# %% [markdown]
# <a href="https://colab.research.google.com/github/crkpersonal/MyRepository/blob/main/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# New AI AGent

# %%
import google.generativeai as genai
from google.colab import userdata

# Configure the API key (stored in Colab secrets)
genai.configure(
    api_key=userdata.get('google_api_key')
)

# List all available models (optional)
# print("Available models:")
# for m in genai.list_models():
#     if "generateContent" in m.supported_generation_methods:
#         print(m.name)

# Load Gemini model
model = genai.GenerativeModel("gemini-pro-latest")

# Define a simple function
def simple_agent(prompt):
    response = model.generate_content(prompt)
    return response.text

# First prompt
question = "Explain AI agent"
answer = simple_agent(question)

# Print output
print("Question:", question)
print("Answer:", answer)
# Out:
# Question: Explain AI agent
# Answer: At its most basic level, an **AI Agent** is an artificial intelligence system that doesn’t just answer questions—it takes action.
#
# While a traditional AI chatbot (like standard ChatGPT) waits for you to ask a question and then gives you an answer, an AI agent is given a **goal**, figures out the steps needed to achieve that goal, and uses tools to get it done.
#
# Here is the easiest way to understand the difference:
# *   **Standard AI:** You say, *"How do I book a flight to London?"* It gives you a list of instructions on how to do it yourself.
# *   **AI Agent:** You say, *"Book me the cheapest flight to London for next Friday."* The agent searches the web, compares prices, navigates the airline website, and uses your saved payment info to buy the ticket.
#
# Think of a standard AI as an **encyclopedia**, and an AI agent as an **intern**.
#
# ---
#
# ### How Does an AI Agent Work?
# ...
